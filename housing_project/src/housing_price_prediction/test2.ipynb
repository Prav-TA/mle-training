# %%
import pandas as pd
from src.housing_price_prediction.ingest_data import fetch_data, load_data
dataset = pd.read_csv(
    "/mnt/c/Users/praveen.ravikuma/Documents/Projects/mle_training/mle-training/housing_project/data/raw/housing.csv"
)
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dataset.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
from src.housing_price_prediction.ingest_data import preprocess_df
processed_data = preprocess_df(dataset)
processed_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                   False                      True
# ...

# %%
from src.housing_price_prediction.ingest_data import feature_engineering, train_test_split


feature_df = feature_engineering(processed_data)

# %%
feature_df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                   False                      True
# ...

# %%
train_df, test_df = train_test_split(feature_df)
train_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
# ...

# %%
import numpy as np
{'median_income':np.random.randint(1,15,100)},
{'median_house_value':np.random.randint(15000,500000,100)},
{'ocean_proximity':np.random.choice(['NEAR BAY', 'INLAND', 'NEAR OCEAN', 'ISLAND'], 100)},
{'income_cat':np.random.randint(1,5,100)},
{'housing_median_age':np.random.randint(1,52,100)},
{'total_rooms':np.random.randint(1,10000,100)},
{'total_bedrooms':np.random.randint(1,5000,100)},
{'population':np.random.randint(1,5000,100)},
{'households':np.random.randint(1,5000,100)},
{'median_income':np.random.randint(1,15,100)},
# Out:
#     median_income
# 0              10
# 1              13
# 2               8
# 3               1
# 4              14
# ..            ...
# 95              3
# 96              4
# 97             10
# 98             14
# 99             10
#
# [100 rows x 1 columns]

# %%
train,test = train_test_split(feature_df)

# %%
train.shape
# Out:
# (16512, 17)

# %%
test.shape
# Out:
# (4128, 17)

# %%
import os
os.getcwd()
# Out:
# '/mnt/c/Users/praveen.ravikuma/Documents/Projects/mle_training/mle-training/housing_project/src/housing_price_prediction'

# %%
a = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath("test2.ipynb"))))
os.makedirs(os.path.dirname(output_path), exist_ok=True)
# Out:
# '/mnt/c/Users/praveen.ravikuma/Documents/Projects/mle_training/mle-training/housing_project'

# %%
os.path.dirname('data/raw')
# Out:
# 'data'

# %%
import os

os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath("test2.ipynb"))))
# Out:
# '/mnt/c/Users/praveen.ravikuma/Documents/Projects/mle_training/mle-training/housing_project'

# %%
import os
import tarfile
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import randint
from six.moves import urllib
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    StratifiedShuffleSplit,
    train_test_split,
)
from sklearn.tree import DecisionTreeRegressor

# matplotlib.use("Agg")
# Suppress warnings from scikit-learn
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
def fetch_data(output_path: str):
    """
    Download and extract the housing dataset in the specified output path.

    Args:
        output_path (str): The directory where the dataset will be downloaded and extracted.
    """
    os.makedirs(output_path, exist_ok=True)
    tgz_path = os.path.join(output_path, "housing.tgz")
    return tgz_path

tgz_path = fetch_data("datasets/housing")
tgz_path
# Out:
# 'datasets/housing/housing.tgz'

# %%
a = housing.sample(30)
a.reset_index(drop=True, inplace=True)
a
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -117.20     34.26                17.0       9419.0          1455.0
# 1     -117.65     34.09                46.0       1214.0           281.0
# 2     -119.79     36.79                33.0       3433.0           785.0
# 3     -118.50     34.04                52.0       3000.0           374.0
# 4     -118.14     34.15                17.0       1896.0           674.0
# 5     -118.34     34.26                37.0       1776.0           301.0
# 6     -118.27     34.16                45.0       1865.0           360.0
# 7     -121.14     38.77                15.0      10282.0          1333.0
# 8     -121.14     40.29                17.0       1944.0           394.0
# 9     -117.16     32.71                 5.0       2508.0           827.0
# 10    -118.31     34.09                30.0       3165.0          1263.0
# 11    -122.41     37.78                52.0       1928.0           836.0
# ...

# %%
from numpy import add
from src.housing_price_prediction.preprocessing import preprocess_df, add_features

b = preprocess_df(a)
b.to_dict()
# Out:
# {'longitude': {0: -117.2,
#   1: -117.65,
#   2: -119.79,
#   3: -118.5,
#   4: -118.14,
#   5: -118.34,
#   6: -118.27,
#   7: -121.14,
#   8: -121.14,
#   9: -117.16,
#   10: -118.31,
#   11: -122.41,
#   12: -118.02,
#   13: -117.14,
#   14: -122.01,
#   15: -121.57,
#   16: -121.46,
#   17: -118.99,
#   18: -122.02,
#   19: -117.06,
#   20: -121.92,
#   21: -123.76,
#   22: -121.98,
#   23: -116.47,
#   24: -118.26,
#   25: -118.94,
#   26: -117.62,
#   27: -121.83,
#   28: -117.97,
#   29: -118.29},
#  'latitude': {0: 34.26,
#   1: 34.09,
#   2: 36.79,
#   3: 34.04,
#   4: 34.15,
#   5: 34.26,
#   6: 34.16,
#   7: 38.77,
#   8: 40.29,
#   9: 32.71,
#   10: 34.09,
#   11: 37.78,
#   12: 33.62,
#   13: 32.79,
#   14: 37.31,
#   15: 39.12,
#   16: 38.61,
#   17: 35.38,
#   18: 37.6,
#   19: 32.75,
#   20: 36.57,
#   21: 41.03,
#   22: 37.33,
#   23: 33.78,
#   24: 33.79,
#   25: 34.18,
#   26: 34.09,
#   27: 37.02,
#   28: 34.13,
#   29: 34.07},
#  'housing_median_age': {0: 17.0,
# ...

# %%
c = add_features(b)
c.to_dict()
# Out:
# {'longitude': {0: -117.2,
#   1: -117.65,
#   2: -119.79,
#   3: -118.5,
#   4: -118.14,
#   5: -118.34,
#   6: -118.27,
#   7: -121.14,
#   8: -121.14,
#   9: -117.16,
#   10: -118.31,
#   11: -122.41,
#   12: -118.02,
#   13: -117.14,
#   14: -122.01,
#   15: -121.57,
#   16: -121.46,
#   17: -118.99,
#   18: -122.02,
#   19: -117.06,
#   20: -121.92,
#   21: -123.76,
#   22: -121.98,
#   23: -116.47,
#   24: -118.26,
#   25: -118.94,
#   26: -117.62,
#   27: -121.83,
#   28: -117.97,
#   29: -118.29},
#  'latitude': {0: 34.26,
#   1: 34.09,
#   2: 36.79,
#   3: 34.04,
#   4: 34.15,
#   5: 34.26,
#   6: 34.16,
#   7: 38.77,
#   8: 40.29,
#   9: 32.71,
#   10: 34.09,
#   11: 37.78,
#   12: 33.62,
#   13: 32.79,
#   14: 37.31,
#   15: 39.12,
#   16: 38.61,
#   17: 35.38,
#   18: 37.6,
#   19: 32.75,
#   20: 36.57,
#   21: 41.03,
#   22: 37.33,
#   23: 33.78,
#   24: 33.79,
#   25: 34.18,
#   26: 34.09,
#   27: 37.02,
#   28: 34.13,
#   29: 34.07},
#  'housing_median_age': {0: 17.0,
# ...

# %%
from numpy import add
from src.housing_price_prediction.preprocessing import preprocess_df,add_features


b = preprocess_df(a)
c = add_features(b)
c.to_dict()
# Out:
# {'longitude': {0: -117.2,
#   1: -117.65,
#   2: -119.79,
#   3: -118.5,
#   4: -118.14,
#   5: -118.34,
#   6: -118.27,
#   7: -121.14,
#   8: -121.14,
#   9: -117.16,
#   10: -118.31,
#   11: -122.41,
#   12: -118.02,
#   13: -117.14,
#   14: -122.01,
#   15: -121.57,
#   16: -121.46,
#   17: -118.99,
#   18: -122.02,
#   19: -117.06,
#   20: -121.92,
#   21: -123.76,
#   22: -121.98,
#   23: -116.47,
#   24: -118.26,
#   25: -118.94,
#   26: -117.62,
#   27: -121.83,
#   28: -117.97,
#   29: -118.29},
#  'latitude': {0: 34.26,
#   1: 34.09,
#   2: 36.79,
#   3: 34.04,
#   4: 34.15,
#   5: 34.26,
#   6: 34.16,
#   7: 38.77,
#   8: 40.29,
#   9: 32.71,
#   10: 34.09,
#   11: 37.78,
#   12: 33.62,
#   13: 32.79,
#   14: 37.31,
#   15: 39.12,
#   16: 38.61,
#   17: 35.38,
#   18: 37.6,
#   19: 32.75,
#   20: 36.57,
#   21: 41.03,
#   22: 37.33,
#   23: 33.78,
#   24: 33.79,
#   25: 34.18,
#   26: 34.09,
#   27: 37.02,
#   28: 34.13,
#   29: 34.07},
#  'housing_median_age': {0: 17.0,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(c)

# %%
X_train.to_dict()
# Out:
# {'longitude': {1: -117.65,
#   24: -118.26,
#   17: -118.99,
#   21: -123.76,
#   9: -117.16,
#   29: -118.29,
#   26: -117.62,
#   13: -117.14,
#   19: -117.06,
#   22: -121.98,
#   8: -121.14,
#   4: -118.14,
#   10: -118.31,
#   0: -117.2,
#   11: -122.41,
#   6: -118.27,
#   5: -118.34,
#   12: -118.02,
#   18: -122.02,
#   2: -119.79,
#   20: -121.92,
#   14: -122.01,
#   7: -121.14,
#   28: -117.97},
#  'latitude': {1: 34.09,
#   24: 33.79,
#   17: 35.38,
#   21: 41.03,
#   9: 32.71,
#   29: 34.07,
#   26: 34.09,
#   13: 32.79,
#   19: 32.75,
#   22: 37.33,
#   8: 40.29,
#   4: 34.15,
#   10: 34.09,
#   0: 34.26,
#   11: 37.78,
#   6: 34.16,
#   5: 34.26,
#   12: 33.62,
#   18: 37.6,
#   2: 36.79,
#   20: 36.57,
#   14: 37.31,
#   7: 38.77,
#   28: 34.13},
#  'housing_median_age': {1: 46.0,
#   24: 30.0,
#   17: 26.0,
#   21: 24.0,
#   9: 5.0,
#   29: 26.0,
#   26: 26.0,
#   13: 35.0,
#   19: 34.0,
#   22: 30.0,
#   8: 17.0,
#   4: 17.0,
#   10: 30.0,
#   0: 17.0,
# ...

# %%
y_train
# Out:
# 1     116300.0
# 24    181500.0
# 17     51000.0
# 21     79800.0
# 9     325000.0
# 29    253100.0
# 26    132000.0
# 13    188600.0
# 19    125900.0
# 22    302400.0
# 8     111500.0
# 4     175000.0
# 10    240600.0
# 0     230900.0
# 11     55000.0
# 6     321200.0
# 5     314900.0
# 12    271400.0
# 18    149600.0
# 2      67500.0
# 20    394400.0
# 14    332700.0
# 7     287800.0
# 28    151700.0
# Name: median_house_value, dtype: float64

# %%
from re import X
from src.housing_price_prediction.prepare_model_data import train_test_split
from src.housing_price_prediction.train import train_forest_with_grid_search

# %%
y_train.to_list()
# Out:
# [116300.0,
#  181500.0,
#  51000.0,
#  79800.0,
#  325000.0,
#  253100.0,
#  132000.0,
#  188600.0,
#  125900.0,
#  302400.0,
#  111500.0,
#  175000.0,
#  240600.0,
#  230900.0,
#  55000.0,
#  321200.0,
#  314900.0,
#  271400.0,
#  149600.0,
#  67500.0,
#  394400.0,
#  332700.0,
#  287800.0,
#  151700.0]

# %%
e = train_forest_with_grid_search(X_train,y_train)

# %%
from src.housing_price_prediction.score import evaluate_model


evaluate_model(e)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 4
#       1 from src.housing_price_prediction.score import evaluate_model
# ----> 4 evaluate_model(e)
#
# TypeError: evaluate_model() missing 2 required positional arguments: 'X_test' and 'y_test'

# %%
assert hasattr(e, "predict")

# %%
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"


def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    os.makedirs(housing_path, exist_ok=True)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path, filter="data")
    housing_tgz.close()


def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)


dataset = fetch_housing_data()
housing = load_housing_data()

# %%
dataset = fetch_data()
housing = load_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dataset = fetch_data()
#       2 housing = load_data()
#
# File /mnt/c/Users/praveen.ravikuma/Documents/Projects/mle_training/mle-training/housing_project/src/housing_price_prediction/ingest_data.py:27, in fetch_data()
#      17 """
#      18 HOUSING_PATH directory.
#      19
#    (...)
#      24     None
#      25 """
#      26 tgz_path = os.path.join(HOUSING_PATH, "housing.tgz")
# ---> 27 urllib.request.urlretrieve(HOUSING_URL, tgz_path)
#      28 with tarfile.open(tgz_path) as housing_tgz:
#      29     housing_tgz.extractall(path=HOUSING_PATH)
#
# File ~/miniforge3/envs/mle-dev/lib/python3.12/urllib/request.py:250, in urlretrieve(url, filename, reporthook, data)
#     248 # Handle temporary file setup.
#     249 if filename:
# --> 250     tfp = open(filename, 'wb')
#     251 else:
# ...
